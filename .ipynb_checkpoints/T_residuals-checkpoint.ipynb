# %% [markdown]
# Exploratory data analysis on T_ERA residuals

# %%
import os
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read in datafile
datadir = ('/media/stijndc/data/datafiles/SAT_EX/netcdf_files_processed/')
data = xr.open_dataset(os.path.join(datadir, 'T_ERA_residuals_8D_correctlat.nc'))
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1553)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 -84.5 -83.5 -82.5 ...
#   * lon      (lon) int64 -180 -179 -178 -177 -176 -175 -174 -173 -172 -171 ...
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-09 1979-01-17 ...
# Data variables:
#     T        (time, lat, lon) float64 3.006 3.005 3.005 3.004 3.003 3.002 ...

# %%
fig, ax = plt.subplots(figsize=(12,6))
data['T'].sel(time='1982-01-01', method='nearest').plot(ax=ax)

# %%
# read in LAI residuals
datadir = ('/media/stijndc/data/datafiles/SAT_EX/netcdf_files_processed/GLASSLAI2/')
LAI = xr.open_dataset(os.path.join(datadir, 'LAI_residuals_9D.nc'))
LAI
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1564)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 -84.5 -83.5 -82.5 ...
#   * lon      (lon) float64 -180.0 -179.0 -178.0 -177.0 -176.0 -175.0 -174.0 ...
#   * time     (time) datetime64[ns] 1982-01-01 1982-01-09 1982-01-17 ...
# Data variables:
#     LAI      (time, lat, lon) float64 nan nan nan nan nan nan nan nan nan ...

# %%
data = data.sel(lat=slice(None,None,-1))

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1553)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 -84.5 -83.5 -82.5 ...
#   * lon      (lon) int64 -180 -179 -178 -177 -176 -175 -174 -173 -172 -171 ...
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-09 1979-01-17 ...
# Data variables:
#     T        (time, lat, lon) float64 3.006 3.005 3.005 3.004 3.003 3.002 ...

# %%
fig, ax = plt.subplots(figsize=(12,6))
data['T'].sel(time='1982-01-01', method='nearest').plot(ax=ax)

#data.to_netcdf('/media/stijndc/data/datafiles/SAT_EX/netcdf_files_processed/T_ERA/residuals/T_ERA_residuals_9D_invertlat.nc')

# %%
test= xr.open_dataset('/media/stijndc/data/datafiles/SAT_EX/netcdf_files_processed/T_ERA_residuals_8D_correctlat.nc')

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1553)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 -84.5 -83.5 -82.5 ...
#   * lon      (lon) int64 -180 -179 -178 -177 -176 -175 -174 -173 -172 -171 ...
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-09 1979-01-17 ...
# Data variables:
#     T        (time, lat, lon) float64 3.006 3.005 3.005 3.004 3.003 3.002 ...

# %%
start_year = '1982'
end_year ='2010'
test = test.sel(time=slice(start_year,end_year))
LAI = LAI.sel(time=slice(start_year,end_year))

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1324)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 -84.5 -83.5 -82.5 ...
#   * lon      (lon) int64 -180 -179 -178 -177 -176 -175 -174 -173 -172 -171 ...
#   * time     (time) datetime64[ns] 1982-01-01 1982-01-09 1982-01-17 ...
# Data variables:
#     T        (time, lat, lon) float64 2.506 2.506 2.506 2.507 2.507 2.507 ...

# %%
LAI
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 1334)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 -84.5 -83.5 -82.5 ...
#   * lon      (lon) float64 -180.0 -179.0 -178.0 -177.0 -176.0 -175.0 -174.0 ...
#   * time     (time) datetime64[ns] 1982-01-01 1982-01-09 1982-01-17 ...
# Data variables:
#     LAI      (time, lat, lon) float64 nan nan nan nan nan nan nan nan nan ...

# %%
LAI.resample('9D', dim='time')

# %%
LAI.to_netcdf
